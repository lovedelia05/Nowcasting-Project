# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
import os
import pytrends 
from pytrends.request import TrendReq
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
from scipy import stats
from sklearn.feature_selection import mutual_info_regression
from tensorflow.keras.models import Model , Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Bidirectional, LayerNormalization, GlobalAveragePooling1D
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import regularizers
from statsmodels.tsa.stattools import adfuller
from plotly.subplots import make_subplots
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, GRU, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score  
from scipy.signal import savgol_filter
# Set up pytrends (english language, timezone UTC+6)
pytrends = TrendReq(hl='en-US', tz=360)
from pytrends import dailydata
import plotly.graph_objects as go

# %%
df=pd.read_csv('FINAL DATASET/final_merged_trends_data.csv')

# %%
df.shape
# Out:
# (2365, 168)

# %%
df.tail()
# Out:
#             date  mp3 download  YouTube  Tubidy download  Netflix  \
# 2360  2025-06-16            55       88               17       25
# 2361  2025-06-17            45       87               14       19
# 2362  2025-06-18            45       84               13       16
# 2363  2025-06-19            46       85               15       17
# 2364  2025-06-20            55       77               16       20
#
#       Goojara movies  Netnaija movies  Disney+  canvas prints  digital art  \
# 2360               8               19       66              0            0
# 2361               6               18       56              0            0
# 2362               6               21       52              0            0
# 2363               6               24       51              0            0
# 2364               7               21       68              0            0
#
#       ...  Flight  Hotel  Guest House  Booking  FlySafair  Lift Airline  \
# 2360  ...      40     71           24       19          9             0
# 2361  ...      38     54           26       29         13             0
# 2362  ...      29     56           24       27         10             0
# 2363  ...      38     57           24       23          8             0
# 2364  ...      34     60           21       20          8             0
#
#       Car Rental        Date  E-Commerce Value  E-Commerce Volume
# 2360          17  2025-06-30      28205.582890                629
# 2361          21  2025-07-01      29144.454690                624
# 2362          14  2025-07-02      40365.723218               1077
# 2363          18  2025-07-03      21466.979056                484
# 2364          18  2025-07-04      13976.384070                295
#
# [5 rows x 168 columns]

# %%
df.head()
# Out:
#          date  mp3 download  YouTube  Tubidy download  Netflix  \
# 0  2018-12-30            80       59                6       18
# 1  2018-12-31            91       73                8       15
# 2  2019-01-01            76       59                6       24
# 3  2019-01-02            65       57                5       17
# 4  2019-01-03            58       56                5       14
#
#    Goojara movies  Netnaija movies  Disney+  canvas prints  digital art  ...  \
# 0               0                0       39              0            0  ...
# 1               0                0       21              0            0  ...
# 2               0                0       36              0            0  ...
# 3               0                0       32              0            0  ...
# 4               0                0       23              0            0  ...
#
#    Flight  Hotel  Guest House  Booking  FlySafair  Lift Airline  Car Rental  \
# 0      63    100           37       22          7             0           9
# 1      57     98           36       23          8             0          12
# 2      73     92           27       31          8             0           8
# 3      64     89           28       27          9             0           8
# 4      56     94           25       28          8             0          11
#
#          Date  E-Commerce Value  E-Commerce Volume
# 0  2018-12-30      48229.459312                456
# 1  2018-12-31      68629.143788                559
# 2  2019-01-01      52162.890120                471
# 3  2019-01-02      66311.844346                736
# 4  2019-01-03      95740.128026                682
#
# [5 rows x 168 columns]

# %%
#drop Date column
df.drop(columns=['Date'], inplace=True)

# %%
df.head()
# Out:
#          date  mp3 download  YouTube  Tubidy download  Netflix  \
# 0  2018-12-30            80       59                6       18
# 1  2018-12-31            91       73                8       15
# 2  2019-01-01            76       59                6       24
# 3  2019-01-02            65       57                5       17
# 4  2019-01-03            58       56                5       14
#
#    Goojara movies  Netnaija movies  Disney+  canvas prints  digital art  ...  \
# 0               0                0       39              0            0  ...
# 1               0                0       21              0            0  ...
# 2               0                0       36              0            0  ...
# 3               0                0       32              0            0  ...
# 4               0                0       23              0            0  ...
#
#    Lodging  Flight  Hotel  Guest House  Booking  FlySafair  Lift Airline  \
# 0        0      63    100           37       22          7             0
# 1        0      57     98           36       23          8             0
# 2        0      73     92           27       31          8             0
# 3        0      64     89           28       27          9             0
# 4        0      56     94           25       28          8             0
#
#    Car Rental  E-Commerce Value  E-Commerce Volume
# 0           9      48229.459312                456
# 1          12      68629.143788                559
# 2           8      52162.890120                471
# 3           8      66311.844346                736
# 4          11      95740.128026                682
#
# [5 rows x 167 columns]

# %%
df['date']
# Out:
# 0       2018-12-30
# 1       2018-12-31
# 2       2019-01-01
# 3       2019-01-02
# 4       2019-01-03
#            ...
# 2360    2025-06-16
# 2361    2025-06-17
# 2362    2025-06-18
# 2363    2025-06-19
# 2364    2025-06-20
# Name: date, Length: 2365, dtype: object

# %%
df.columns
# Out:
# Index(['date', 'mp3 download', 'YouTube', 'Tubidy download', 'Netflix',
#        'Goojara movies', 'Netnaija movies', 'Disney+', 'canvas prints',
#        'digital art',
#        ...
#        'Lodging', 'Flight', 'Hotel', 'Guest House', 'Booking', 'FlySafair',
#        'Lift Airline', 'Car Rental', 'E-Commerce Value', 'E-Commerce Volume'],
#       dtype='object', length=167)

# %%
# Ensure 'date' is datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

plt.figure(figsize=(12, 6))

plt.plot(df['date'], df['Goojara movies'], linewidth=2, label='Goojara movies')
plt.plot(df['date'], df['YouTube'], linewidth=2, label='YouTube')
plt.plot(df['date'], df['Cell C'], linewidth=2, label='Cell C')

# Styling
plt.title("Search Trends Over Time", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Search Interest", fontsize=12)

# Format x-axis to avoid clutter
ax = plt.gca()  # Get current axis
ax.xaxis.set_major_locator(mdates.AutoDateLocator())  # Automatically space out dates
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))  # Format as 'Jul 2024', etc.

plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(frameon=False, fontsize=11)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(14, 6))
#  E-Commerce Transactions: Volume
#plt.subplot(1, 2, 2)
plt.plot(df['date'], df['E-Commerce Volume'], linewidth=2, color='green', label='E-Commerce Volume')
plt.title("E-Commerce Transactions: Volume Over Time", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Volume", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(frameon=False, fontsize=11)

# %%
# Plot 1: E-Commerce Transactions: Value
plt.figure(figsize=(14, 6))
plt.plot(df['date'], df['E-Commerce Value'], linewidth=2, color='blue', label='E-Commerce Value')
plt.title("E-Commerce Transactions: Value Over Time", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(frameon=False, fontsize=11)

# %% [markdown]
# # value and volume data frame

# %%
# Drop target columns from the feature set
X = df.drop(columns=['E-Commerce Value', 'E-Commerce Volume'])

# Keep the target columns separately
y_value = df['E-Commerce Value']
y_volume = df['E-Commerce Volume']

# %%
# Value DataFrame
df_value = X.copy()
df_value['E-Commerce Value'] = y_value

# Volume DataFrame
df_volume = X.copy()
df_volume['E-Commerce Volume'] = y_volume

# %%
print ("Value DataFrame shape:", df_value.shape)
print ("Volume DataFrame shape:", df_volume.shape)
# Out:
# Value DataFrame shape: (2365, 166)
# Volume DataFrame shape: (2365, 166)

# %%
df_value.head()
# Out:
#         date  mp3 download  YouTube  Tubidy download  Netflix  Goojara movies  \
# 0 2018-12-30            80       59                6       18               0
# 1 2018-12-31            91       73                8       15               0
# 2 2019-01-01            76       59                6       24               0
# 3 2019-01-02            65       57                5       17               0
# 4 2019-01-03            58       56                5       14               0
#
#    Netnaija movies  Disney+  canvas prints  digital art  ...  Football  \
# 0                0       39              0            0  ...        82
# 1                0       21              0            0  ...        53
# 2                0       36              0            0  ...        78
# 3                0       32              0            0  ...        64
# 4                0       23              0            0  ...        64
#
#    Lodging  Flight  Hotel  Guest House  Booking  FlySafair  Lift Airline  \
# 0        0      63    100           37       22          7             0
# 1        0      57     98           36       23          8             0
# 2        0      73     92           27       31          8             0
# 3        0      64     89           28       27          9             0
# 4        0      56     94           25       28          8             0
#
#    Car Rental  E-Commerce Value
# 0           9      48229.459312
# 1          12      68629.143788
# 2           8      52162.890120
# 3           8      66311.844346
# 4          11      95740.128026
#
# [5 rows x 166 columns]

# %%
df_volume.head()
# Out:
#         date  mp3 download  YouTube  Tubidy download  Netflix  Goojara movies  \
# 0 2018-12-30            80       59                6       18               0
# 1 2018-12-31            91       73                8       15               0
# 2 2019-01-01            76       59                6       24               0
# 3 2019-01-02            65       57                5       17               0
# 4 2019-01-03            58       56                5       14               0
#
#    Netnaija movies  Disney+  canvas prints  digital art  ...  Football  \
# 0                0       39              0            0  ...        82
# 1                0       21              0            0  ...        53
# 2                0       36              0            0  ...        78
# 3                0       32              0            0  ...        64
# 4                0       23              0            0  ...        64
#
#    Lodging  Flight  Hotel  Guest House  Booking  FlySafair  Lift Airline  \
# 0        0      63    100           37       22          7             0
# 1        0      57     98           36       23          8             0
# 2        0      73     92           27       31          8             0
# 3        0      64     89           28       27          9             0
# 4        0      56     94           25       28          8             0
#
#    Car Rental  E-Commerce Volume
# 0           9                456
# 1          12                559
# 2           8                471
# 3           8                736
# 4          11                682
#
# [5 rows x 166 columns]

# %%
import tensorflow as tf
tf.config.set_visible_devices([],'GPU')

# %% [markdown]
# # value feature selection
# 1. Excessive zeros
# 2.  Mutual Information Feature Selection
# 3. correlation

# %%
df_value.columns
# Out:
# Index(['date', 'mp3 download', 'YouTube', 'Tubidy download', 'Netflix',
#        'Goojara movies', 'Netnaija movies', 'Disney+', 'canvas prints',
#        'digital art',
#        ...
#        'Football', 'Lodging', 'Flight', 'Hotel', 'Guest House', 'Booking',
#        'FlySafair', 'Lift Airline', 'Car Rental', 'E-Commerce Value'],
#       dtype='object', length=166)

# %%
threshold = 0.8 

# Calculate percentage of zeros in each column
zero_ratio = (df_value == 0).sum() / len(df_value)

# Select columns with >= 80% zeros
cols_with_80pct_zeros = zero_ratio[zero_ratio >= threshold].index.tolist()

print("Columns with >= 80% zeros:")
print(cols_with_80pct_zeros)
# Out:
# Columns with >= 80% zeros:
# ['canvas prints', 'digital art', 'textbook', 'Amazon books', 'Uber Eats', '60 sixty', 'monitor stand', 'FNB (First National Bank)', 'Investment app', 'trading platforms', 'mutual funds', 'beverage', 'Grocery delivery', 'PS5 games', 'video games', 'Mobile app', 'Pharmaceutical drugs', 'COVID-19 vaccine', 'Insurance plan', 'Vitamins online', 'Immune booster', 'Physician', 'Lottostar (Pty) Ltd', 'DIY kits', 'art supplies', 'Takealot.com', 'Defy Appliances', 'magazines', 'news subscription', 'Online Marketplace', 'Pet shop', 'Remax Hub', 'The Parks Lifestyle Apartments', 'Eazi Real Estate', 'Property sales', 'Gambling', 'Arsenal Store', 'Lodging', 'Lift Airline']

# %%
len(cols_with_80pct_zeros)
# Out:
# 39

# %%
# Pick 3 columns to visualize
cols_to_plot = ['canvas prints', 'digital art', 'textbook']

plt.figure(figsize=(12, 6))

for col in cols_to_plot:
    plt.plot(df_value['date'], df_value[col], label=col)

plt.xlabel("Date")
plt.ylabel("Google Trends Value")
plt.title("Columns with >=80% Zeros")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# Pick 3 columns to visualize
cols_to_plot = [ 'Amazon books', 'Uber Eats', '60 sixty', 'DStv Stream']

plt.figure(figsize=(12, 6))

for col in cols_to_plot:
    plt.plot(df_value['date'], df_value[col], label=col)

plt.xlabel("Date")
plt.ylabel("Google Trends Value")
plt.title("Columns with >=80% Zeros")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#list comprehension
cols_with_low_zero = [
    col for col in df_value.columns 
    if col not in cols_with_80pct_zeros
]

# %%
print('columns with few zeros in the data ')
cols_with_low_zero
# Out:
# columns with few zeros in the data
# ['date',
#  'mp3 download',
#  'YouTube',
#  'Tubidy download',
#  'Netflix',
#  'Goojara movies',
#  'Netnaija movies',
#  'Disney+',
#  'We Buy Cars',
#  'AutoTrader',
#  'Toyota',
#  'BMW',
#  'Mercedes Benz',
#  'Cars for Sale',
#  'Hyundai',
#  'Volkswagen Polo',
#  'Cars',
#  'Renault Kiger',
#  'Clicks',
#  'Dischem',
#  'Avon',
#  'CeraVe',
#  'Perfume',
#  'Hair',
#  'Makeup',
#  'Cosmetics',
#  'Beauty Salon',
#  'Exclusive Books',
#  'Download',
#  'Wattpad',
#  'ebook',
#  'poetry',
#  'novel',
#  'Hollywoodbets',
#  'The Courier Guy',
#  'ShopRite',
#  'Steers',
#  'Betway',
#  'Buffalo Logistics',
#  'Bolt',
#  'PaymeNow',
#  'DStv Stream',
#  'Download.1',
#  'Mr Price',
#  'Makro',
#  'Microsoft',
#  'Apple',
#  'Samsung',
#  'computer',
#  'laptop',
#  'Online banking',
#  'Capitec Bank',
#  'Standard Bank',
#  'Nedbank',
#  'Loan',
#  'stocks',
#  'KFC',
#  "McDonald's",
#  'Checkers',
#  'Woolworths',
#  'Pick n Pay',
#  'Nandos',
#  'Burger King',
#  'Debonairs Pizza',
#  'Powerball',
#  'Xbox games',
#  'Genshin Impact',
#  'Lotto',
#  'Game',
#  'Betfred',
#  'Medicine',
#  'Tablets',
#  'Netcare',
#  'mediclinic',
#  'Daily Lotto',
#  'Mr Price Home',
#  'Decofurn',
#  'furniture',
#  'Makro.1',
#  'Builders',
#  'paints',
#  'Pep Home',
#  'plant',
#  'iPhone',
#  'Vodacom',
#  'MTN',
#  'Telkom',
#  'Samsung.1',
#  'Huawei',
#  'Mobile app.1',
#  'Download.2',
#  'Gmail',
#  'Cell C',
#  'Facebook',
#  'Dog Food',
#  'Puppies for Sale',
#  'Property24',
#  'Private Property',
#  'Houses for Sale',
#  'Flats to rent',
#  'Room to rent',
#  'Real Estate',
#  'Sales',
#  'Black friday',
#  'Sneakers',
#  'Online Shopping',
#  'Shein',
#  'Adidas',
#  'Puma',
#  'Nike',
#  'sportscene',
#  'clothing',
#  'Kaizer Chiefs',
#  'Orlando Pirates',
#  'Sundowns',
#  'Premier League',
#  'Soccer Laduma',
#  'FIFA World Cup',
#  'Tickets',
#  'Football',
#  'Flight',
#  'Hotel',
#  'Guest House',
#  'Booking',
#  'FlySafair',
#  'Car Rental',
#  'E-Commerce Value']

# %%
# Pick your columns
cols_to_plot = ['mp3 download', 'YouTube', 'Tubidy download', 'Netflix']

plt.figure(figsize=(14, 7))

for col in cols_to_plot:
    plt.plot(df_value['date'], df_value[col], label=col)

plt.xlabel("Date")
plt.ylabel("Google Trends Value")
plt.title("Google Trends: Keywords with less than 70% zeros")
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# Pick your columns
cols_to_plot = ['Clicks',
 'Dischem',
 'Avon',
 'CeraVe',
 'Perfume']

plt.figure(figsize=(14, 7))

for col in cols_to_plot:
    plt.plot(df_value['date'], df_value[col], label=col)

plt.xlabel("Date")
plt.ylabel("Google Trends Value")
plt.title("Google Trends: Keywords with less than 70% zeros")
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# %%
 # Show total before dropping
print(f"Total columns before dropping: {len(df_value.columns)}")
# Drop the columns with 70% zeros in the time series
df_value_cleaned = df_value.drop(columns=cols_with_80pct_zeros)

print(f"Dropped {len(cols_with_80pct_zeros)} columns with >=80% zeros.")
print("Remaining columns:", len(df_value_cleaned.columns.tolist()))
# Out:
# Total columns before dropping: 166
# Dropped 39 columns with >=80% zeros.
# Remaining columns: 127

# %%
df_value_cleaned.head()
# Out:
#         date  mp3 download  YouTube  Tubidy download  Netflix  Goojara movies  \
# 0 2018-12-30            80       59                6       18               0
# 1 2018-12-31            91       73                8       15               0
# 2 2019-01-01            76       59                6       24               0
# 3 2019-01-02            65       57                5       17               0
# 4 2019-01-03            58       56                5       14               0
#
#    Netnaija movies  Disney+  We Buy Cars  AutoTrader  ...  FIFA World Cup  \
# 0                0       39            7          17  ...               0
# 1                0       21            5          15  ...               0
# 2                0       36            9          20  ...               0
# 3                0       32           11          22  ...               0
# 4                0       23           13          23  ...               0
#
#    Tickets  Football  Flight  Hotel  Guest House  Booking  FlySafair  \
# 0       19        82      63    100           37       22          7
# 1       24        53      57     98           36       23          8
# 2       16        78      73     92           27       31          8
# 3       18        64      64     89           28       27          9
# 4       18        64      56     94           25       28          8
#
#    Car Rental  E-Commerce Value
# 0           9      48229.459312
# 1          12      68629.143788
# 2           8      52162.890120
# 3           8      66311.844346
# 4          11      95740.128026
#
# [5 rows x 127 columns]

# %%
# Pick your columns
cols_to_plot = ['Goojara movies', 'Netnaija movies', 'FIFA World Cup']

plt.figure(figsize=(12, 6))

for col in cols_to_plot:
    plt.plot(df_value_cleaned['date'], df_value_cleaned[col], label=col)

plt.xlabel("Date")
plt.ylabel("Google Trends Value")
plt.title("Google Trends: Movies & FIFA World Cup")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_value_cleaned.columns
# Out:
# Index(['date', 'mp3 download', 'YouTube', 'Tubidy download', 'Netflix',
#        'Goojara movies', 'Netnaija movies', 'Disney+', 'We Buy Cars',
#        'AutoTrader',
#        ...
#        'FIFA World Cup', 'Tickets', 'Football', 'Flight', 'Hotel',
#        'Guest House', 'Booking', 'FlySafair', 'Car Rental',
#        'E-Commerce Value'],
#       dtype='object', length=127)

# %%
# Convert 'date' column to datetime (if not already)
df_value_cleaned['date'] = pd.to_datetime(df_value_cleaned['date'])

# Set 'date' as index
df_value_cleaned.set_index('date', inplace=True)

# %%
df_value_cleaned.head()
# Out:
#             mp3 download  YouTube  Tubidy download  Netflix  Goojara movies  \
# date
# 2018-12-30            80       59                6       18               0
# 2018-12-31            91       73                8       15               0
# 2019-01-01            76       59                6       24               0
# 2019-01-02            65       57                5       17               0
# 2019-01-03            58       56                5       14               0
#
#             Netnaija movies  Disney+  We Buy Cars  AutoTrader  Toyota  ...  \
# date                                                                   ...
# 2018-12-30                0       39            7          17      67  ...
# 2018-12-31                0       21            5          15      56  ...
# 2019-01-01                0       36            9          20      59  ...
# 2019-01-02                0       32           11          22      71  ...
# 2019-01-03                0       23           13          23      68  ...
#
#             FIFA World Cup  Tickets  Football  Flight  Hotel  Guest House  \
# date
# 2018-12-30               0       19        82      63    100           37
# 2018-12-31               0       24        53      57     98           36
# 2019-01-01               0       16        78      73     92           27
# 2019-01-02               0       18        64      64     89           28
# 2019-01-03               0       18        64      56     94           25
#
#             Booking  FlySafair  Car Rental  E-Commerce Value
# date
# 2018-12-30       22          7           9      48229.459312
# 2018-12-31       23          8          12      68629.143788
# 2019-01-01       31          8           8      52162.890120
# 2019-01-02       27          9           8      66311.844346
# 2019-01-03       28          8          11      95740.128026
#
# [5 rows x 126 columns]

# %%
# Separate features and target
X = df_value_cleaned.drop(columns=['E-Commerce Value'])
y = df_value_cleaned['E-Commerce Value']

# Mutual Information feature selection
from sklearn.feature_selection import SelectKBest, mutual_info_regression

# Initialize selector 
selector = SelectKBest(score_func=mutual_info_regression, k='all')

# Fit on your features
selector.fit(X, y)
# Out:
# SelectKBest(k='all',
#             score_func=<function mutual_info_regression at 0x0000025782A2E980>)

# %%
# Get scores
mi_scores = selector.scores_
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})

# %%
mi_df = mi_df.sort_values(by='MI Score', ascending=False).head(30)

# Plot
plt.figure(figsize=(10,8))
plt.barh(mi_df['Feature'], mi_df['MI Score'], color='skyblue')
plt.gca().invert_yaxis()
plt.title("Top 30 Features by Mutual Information with E-Commerce Value")
plt.xlabel("Mutual Information Score")
plt.show()

# %%
# Filter features with MI Score >= 0.1
mi_df_filtered = mi_df[mi_df['MI Score'] >= 0.1].sort_values(by='MI Score', ascending=False)

# Plot
plt.figure(figsize=(10, 8))
plt.barh(mi_df_filtered['Feature'], mi_df_filtered['MI Score'], color='lightgreen')
plt.gca().invert_yaxis()
plt.title("Features with Mutual Information Score ≥ 1")
plt.xlabel("Mutual Information Score")
plt.show()

# %%
print("Features with MI Score >= 0.1:")

# Get the list of feature names
print (mi_df_filtered['Feature'].tolist())
# Out:
# Features with MI Score >= 0.1:
# ['Football', 'YouTube', 'DStv Stream', 'Avon', 'Goojara movies', 'Soccer Laduma', 'Property24', 'Vodacom', 'We Buy Cars', 'Telkom', 'Samsung', 'Standard Bank', 'Game', 'Gmail', 'The Courier Guy', 'Cars for Sale', 'AutoTrader', 'computer', 'Online banking', 'Netnaija movies', 'Netcare', 'clothing', 'Loan', 'MTN', 'Betfred', 'Online Shopping', 'Puma']

# %%
# Optionally, subset your X data to keep only these features
X_selected = X[mi_df_filtered['Feature'].tolist()]
X_selected.head()
# Out:
#             Football  YouTube  DStv Stream  Avon  Goojara movies  \
# date
# 2018-12-30        82       59            0    34               0
# 2018-12-31        53       73            0    29               0
# 2019-01-01        78       59            0    39               0
# 2019-01-02        64       57            0    42               0
# 2019-01-03        64       56            0    45               0
#
#             Soccer Laduma  Property24  Vodacom  We Buy Cars  Telkom  ...  \
# date                                                                 ...
# 2018-12-30             12          23       46            7      61  ...
# 2018-12-31             12          22       58            5      72  ...
# 2019-01-01             12          30       54            9      58  ...
# 2019-01-02             16          31       67           11      81  ...
# 2019-01-03             16          34       65           13      71  ...
#
#             computer  Online banking  Netnaija movies  Netcare  clothing  \
# date
# 2018-12-30        13              17                0       29        63
# 2018-12-31        11              28                0       26        53
# 2019-01-01        12              18                0       40        50
# 2019-01-02        14              26                0       45        58
# 2019-01-03        17              25                0       58        53
#
#             Loan  MTN  Betfred  Online Shopping  Puma
# date
# 2018-12-30    51   29        0               34    19
# 2018-12-31    60   32        0               25    16
# 2019-01-01    40   29        0               36    12
# 2019-01-02    92   42        0               39     9
# 2019-01-03    94   35        0               35    10
#
# [5 rows x 27 columns]

# %%
X_selected.shape
# Out:
# (2365, 27)

# %%
# Compute correlation matrix
corr_matrix = X_selected.corr()

# Plot the correlation matrix
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title("Correlation Matrix of Selected Features")
plt.show()

# %%
# find highly correlated pairs 
threshold = 0.8
high_corr = np.where(corr_matrix >= threshold)
high_corr_pairs = [(corr_matrix.index[x], corr_matrix.columns[y], corr_matrix.iloc[x, y])
                   for x, y in zip(*high_corr) if x != y and x < y]

print(f"Highly correlated feature pairs (>= {threshold}):")
for f1, f2, corr_val in high_corr_pairs:
    print(f"{f1} - {f2}: {corr_val:.2f}")
# Out:
# Highly correlated feature pairs (>= 0.8):
# DStv Stream - Betfred: 0.85
# Vodacom - Telkom: 0.86
# Vodacom - Online Shopping: 0.83
# Telkom - Online Shopping: 0.83
# Standard Bank - Online banking: 0.92

# %%
# Compute correlation of each feature with target y
feature_target_corr = df.corrwith(y).to_dict()

# Select one feature per pair based on higher correlation with y
selected_features = []
for f1, f2, corr_val in high_corr_pairs:
    score1 = abs(feature_target_corr.get(f1, 0))
    score2 = abs(feature_target_corr.get(f2, 0))
    # Pick the feature more strongly correlated with y
    selected = f1 if score1 >= score2 else f2
    selected_features.append(selected)

# Remove duplicates
selected_features = list(set(selected_features))

print("Selected features most correlated to target 'value':")
print(selected_features)
# Out:
# Selected features most correlated to target 'value':
# ['Betfred', 'Online banking', 'Telkom', 'Online Shopping']

# %%
# Initialize features to drop
features_to_drop = []

for f1, f2, corr_val in high_corr_pairs:
    # Drop the feature that is not in selected_features
    if f1 in selected_features and f2 not in selected_features:
        features_to_drop.append(f2)
    elif f2 in selected_features and f1 not in selected_features:
        features_to_drop.append(f1)
    else:
        # If neither is in selected_features, drop one arbitrarily (e.g., f2)
        if f2 in X_selected.columns:
            features_to_drop.append(f2)

# Remove duplicates
features_to_drop = list(set(features_to_drop))

# Drop redundant features from X_selected
X_final = X_selected.drop(columns=features_to_drop, errors='ignore')

print("Final features after removing highly correlated redundancies:")
print(X_final.columns.tolist())
# Out:
# Final features after removing highly correlated redundancies:
# ['Football', 'YouTube', 'Avon', 'Goojara movies', 'Soccer Laduma', 'Property24', 'We Buy Cars', 'Telkom', 'Samsung', 'Game', 'Gmail', 'The Courier Guy', 'Cars for Sale', 'AutoTrader', 'computer', 'Online banking', 'Netnaija movies', 'Netcare', 'clothing', 'Loan', 'MTN', 'Betfred', 'Puma']

# %%
X_final.shape
# Out:
# (2365, 23)

# %%
X_final.head()
# Out:
#             Football  YouTube  Avon  Goojara movies  Soccer Laduma  \
# date
# 2018-12-30        82       59    34               0             12
# 2018-12-31        53       73    29               0             12
# 2019-01-01        78       59    39               0             12
# 2019-01-02        64       57    42               0             16
# 2019-01-03        64       56    45               0             16
#
#             Property24  We Buy Cars  Telkom  Samsung  Game  ...  AutoTrader  \
# date                                                        ...
# 2018-12-30          23            7      61       59    11  ...          17
# 2018-12-31          22            5      72       59    13  ...          15
# 2019-01-01          30            9      58       62    13  ...          20
# 2019-01-02          31           11      81       67    13  ...          22
# 2019-01-03          34           13      71       64    12  ...          23
#
#             computer  Online banking  Netnaija movies  Netcare  clothing  \
# date
# 2018-12-30        13              17                0       29        63
# 2018-12-31        11              28                0       26        53
# 2019-01-01        12              18                0       40        50
# 2019-01-02        14              26                0       45        58
# 2019-01-03        17              25                0       58        53
#
#             Loan  MTN  Betfred  Puma
# date
# 2018-12-30    51   29        0    19
# 2018-12-31    60   32        0    16
# 2019-01-01    40   29        0    12
# 2019-01-02    92   42        0     9
# 2019-01-03    94   35        0    10
#
# [5 rows x 23 columns]

# %%
# Save to CSV 
X_final.to_csv("selected_google_trends_value.csv")

print("Saved selected features  to 'selected_google_trends_value.csv'")
X_final.head()
# Out:
# Saved selected features  to 'selected_google_trends_value.csv'
#             Football  YouTube  Avon  Goojara movies  Soccer Laduma  \
# date
# 2018-12-30        82       59    34               0             12
# 2018-12-31        53       73    29               0             12
# 2019-01-01        78       59    39               0             12
# 2019-01-02        64       57    42               0             16
# 2019-01-03        64       56    45               0             16
#
#             Property24  We Buy Cars  Telkom  Samsung  Game  ...  AutoTrader  \
# date                                                        ...
# 2018-12-30          23            7      61       59    11  ...          17
# 2018-12-31          22            5      72       59    13  ...          15
# 2019-01-01          30            9      58       62    13  ...          20
# 2019-01-02          31           11      81       67    13  ...          22
# 2019-01-03          34           13      71       64    12  ...          23
#
#             computer  Online banking  Netnaija movies  Netcare  clothing  \
# date
# 2018-12-30        13              17                0       29        63
# 2018-12-31        11              28                0       26        53
# 2019-01-01        12              18                0       40        50
# 2019-01-02        14              26                0       45        58
# 2019-01-03        17              25                0       58        53
#
#             Loan  MTN  Betfred  Puma
# date
# 2018-12-30    51   29        0    19
# 2018-12-31    60   32        0    16
# 2019-01-01    40   29        0    12
# 2019-01-02    92   42        0     9
# 2019-01-03    94   35        0    10
#
# [5 rows x 23 columns]

# %% [markdown]
# # Volume Feature Selector

# %%
df_volume.head()
# Out:
#         date  mp3 download  YouTube  Tubidy download  Netflix  Goojara movies  \
# 0 2018-12-30            80       59                6       18               0
# 1 2018-12-31            91       73                8       15               0
# 2 2019-01-01            76       59                6       24               0
# 3 2019-01-02            65       57                5       17               0
# 4 2019-01-03            58       56                5       14               0
#
#    Netnaija movies  Disney+  canvas prints  digital art  ...  Football  \
# 0                0       39              0            0  ...        82
# 1                0       21              0            0  ...        53
# 2                0       36              0            0  ...        78
# 3                0       32              0            0  ...        64
# 4                0       23              0            0  ...        64
#
#    Lodging  Flight  Hotel  Guest House  Booking  FlySafair  Lift Airline  \
# 0        0      63    100           37       22          7             0
# 1        0      57     98           36       23          8             0
# 2        0      73     92           27       31          8             0
# 3        0      64     89           28       27          9             0
# 4        0      56     94           25       28          8             0
#
#    Car Rental  E-Commerce Volume
# 0           9                456
# 1          12                559
# 2           8                471
# 3           8                736
# 4          11                682
#
# [5 rows x 166 columns]

# %%
df_volume.shape
# Out:
# (2365, 166)

# %%
threshold = 0.8 

# Calculate percentage of zeros in each column
zero_ratio = (df_volume == 0).sum() / len(df_volume)

# Select columns with >= 80% zeros
cols_with_80pct_zeros = zero_ratio[zero_ratio >= threshold].index.tolist()

print("Columns with >= 80% zeros:")
print(cols_with_80pct_zeros)
# Out:
# Columns with >= 80% zeros:
# ['canvas prints', 'digital art', 'textbook', 'Amazon books', 'Uber Eats', '60 sixty', 'monitor stand', 'FNB (First National Bank)', 'Investment app', 'trading platforms', 'mutual funds', 'beverage', 'Grocery delivery', 'PS5 games', 'video games', 'Mobile app', 'Pharmaceutical drugs', 'COVID-19 vaccine', 'Insurance plan', 'Vitamins online', 'Immune booster', 'Physician', 'Lottostar (Pty) Ltd', 'DIY kits', 'art supplies', 'Takealot.com', 'Defy Appliances', 'magazines', 'news subscription', 'Online Marketplace', 'Pet shop', 'Remax Hub', 'The Parks Lifestyle Apartments', 'Eazi Real Estate', 'Property sales', 'Gambling', 'Arsenal Store', 'Lodging', 'Lift Airline']

# %%
len(cols_with_80pct_zeros)
# Out:
# 39

# %%
#list comprehension
cols_with_low_zero = [
    col for col in df_volume.columns 
    if col not in cols_with_80pct_zeros
]

# %%
 # Show total before dropping
print(f"Total columns before dropping: {len(df_volume.columns)}")
# Drop the columns with 80% zeros in the time series
df_volume_cleaned = df_volume.drop(columns=cols_with_80pct_zeros)

print(f"Dropped {len(cols_with_80pct_zeros)} columns with >=80% zeros.")
print("Remaining columns:", len(df_volume_cleaned.columns.tolist()))
# Out:
# Total columns before dropping: 166
# Dropped 39 columns with >=80% zeros.
# Remaining columns: 127

# %%
df_volume_cleaned.head()
# Out:
#         date  mp3 download  YouTube  Tubidy download  Netflix  Goojara movies  \
# 0 2018-12-30            80       59                6       18               0
# 1 2018-12-31            91       73                8       15               0
# 2 2019-01-01            76       59                6       24               0
# 3 2019-01-02            65       57                5       17               0
# 4 2019-01-03            58       56                5       14               0
#
#    Netnaija movies  Disney+  We Buy Cars  AutoTrader  ...  FIFA World Cup  \
# 0                0       39            7          17  ...               0
# 1                0       21            5          15  ...               0
# 2                0       36            9          20  ...               0
# 3                0       32           11          22  ...               0
# 4                0       23           13          23  ...               0
#
#    Tickets  Football  Flight  Hotel  Guest House  Booking  FlySafair  \
# 0       19        82      63    100           37       22          7
# 1       24        53      57     98           36       23          8
# 2       16        78      73     92           27       31          8
# 3       18        64      64     89           28       27          9
# 4       18        64      56     94           25       28          8
#
#    Car Rental  E-Commerce Volume
# 0           9                456
# 1          12                559
# 2           8                471
# 3           8                736
# 4          11                682
#
# [5 rows x 127 columns]

# %%
df_volume_cleaned['date'] = pd.to_datetime(df_volume_cleaned['date'])  
df_volume_cleaned.set_index('date', inplace=True)

# %%
X = df_volume_cleaned.drop(columns=[target_col])
y = df_volume_cleaned[target_col]

# %%
# Compute MI
mi_scores = mutual_info_regression(X, y)
mi_df = pd.DataFrame({'Feature': X.columns, 'MI': mi_scores})
# sorting the scores
mi_df= mi_df.sort_values(by="MI", ascending=False)

# %%
# Plot  MI scores
top_n = 40
plt.figure(figsize=(10, 6))
plt.barh(mi_df['Feature'].head(top_n), mi_df['MI'].head(top_n))
plt.gca().invert_yaxis() 
plt.xlabel("Mutual Information (MI)")
plt.title(f"Top {top_n} Features by Mutual Information with E-Commerce Volume")
plt.show()

# %%
# Filter features with MI >= 0.1
mi_threshold = 0.1
important_features = mi_df[mi_df['MI'] >= mi_threshold]
print ("total features with >= 0.1 MI score:",len(important_features))
# If you just need the names
selected_features = important_features['Feature'].tolist()
print("\nSelected feature names:", selected_features)
# Out:
# total features with >= 0.1 MI score: 29
#
# Selected feature names: ['Football', 'Avon', 'We Buy Cars', 'Soccer Laduma', 'The Courier Guy', 'Vodacom', 'Sneakers', 'Property24', 'Standard Bank', 'Game', 'Gmail', 'MTN', 'Tickets', 'YouTube', 'Pick n Pay', 'Goojara movies', 'Samsung', 'Disney+', 'Huawei', 'DStv Stream', 'Guest House', 'Samsung.1', 'Online banking', 'Online Shopping', 'AutoTrader', 'laptop', 'Telkom', 'Cars for Sale', 'Nike']

# %%
# Subset X to keep only the important features
Volume_selected = X[selected_features]

print("Shape before:", X.shape)
print("Shape after:", Volume_selected.shape)
# Out:
# Shape before: (2365, 125)
# Shape after: (2365, 29)

# %%
Volume_selected.columns
# Out:
# Index(['Football', 'Avon', 'We Buy Cars', 'Soccer Laduma', 'The Courier Guy',
#        'Vodacom', 'Sneakers', 'Property24', 'Standard Bank', 'Game', 'Gmail',
#        'MTN', 'Tickets', 'YouTube', 'Pick n Pay', 'Goojara movies', 'Samsung',
#        'Disney+', 'Huawei', 'DStv Stream', 'Guest House', 'Samsung.1',
#        'Online banking', 'Online Shopping', 'AutoTrader', 'laptop', 'Telkom',
#        'Cars for Sale', 'Nike'],
#       dtype='object')

# %%
Volume_selected.head()
# Out:
#             Football  Avon  We Buy Cars  Soccer Laduma  The Courier Guy  \
# date
# 2018-12-30        82    34            7             12                0
# 2018-12-31        53    29            5             12                0
# 2019-01-01        78    39            9             12                0
# 2019-01-02        64    42           11             16                0
# 2019-01-03        64    45           13             16                0
#
#             Vodacom  Sneakers  Property24  Standard Bank  Game  ...  \
# date                                                            ...
# 2018-12-30       46        55          23             30    11  ...
# 2018-12-31       58        63          22             55    13  ...
# 2019-01-01       54        63          30             33    13  ...
# 2019-01-02       67        55          31             53    13  ...
# 2019-01-03       65        60          34             52    12  ...
#
#             DStv Stream  Guest House  Samsung.1  Online banking  \
# date
# 2018-12-30            0           37         24              17
# 2018-12-31            0           36         29              28
# 2019-01-01            0           27         26              18
# 2019-01-02            0           28         31              26
# 2019-01-03            0           25         30              25
#
#             Online Shopping  AutoTrader  laptop  Telkom  Cars for Sale  Nike
# date
# 2018-12-30               34          17      34      61             25    55
# 2018-12-31               25          15      31      72             20    49
# 2019-01-01               36          20      30      58             27    49
# 2019-01-02               39          22      47      81             30    54
# 2019-01-03               35          23      38      71             27    43
#
# [5 rows x 29 columns]

# %%
# Correlation of the selected features across the full dataset
volume_corr_matrix = Volume_selected.corr()

plt.figure(figsize=(20, 10))
sns.heatmap(volume_corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Correlation Matrix of Selected Features")
plt.show()

# %%
# find highly correlated pairs 
threshold = 0.8
high_corr = np.where(volume_corr_matrix >= threshold)
high_corr_pairs = [(volume_corr_matrix.index[x], volume_corr_matrix.columns[y], volume_corr_matrix.iloc[x, y])
                   for x, y in zip(*high_corr) if x != y and x < y]

print(f"Highly correlated feature pairs (>= {threshold}):")
for f1, f2, corr_val in high_corr_pairs:
    print(f"{f1} - {f2}: {corr_val:.2f}")
# Out:
# Highly correlated feature pairs (>= 0.8):
# Vodacom - Samsung.1: 0.84
# Vodacom - Online Shopping: 0.83
# Vodacom - Telkom: 0.86
# Sneakers - Samsung.1: 0.88
# Sneakers - Online Shopping: 0.84
# Standard Bank - Online banking: 0.92
# Online Shopping - Telkom: 0.83

# %%
# Decide which feature to drop using correlation to the target
# Compute correlation of features with target
feature_target_corr = Volume_selected.join(y.rename("E-Commerce Value")).corr()["E-Commerce Value"].drop("E-Commerce Value")

to_drop = set()
for f1, f2, corr_val in high_corr_pairs:
    if feature_target_corr[f1] >= feature_target_corr[f2]:
        to_drop.add(f2)
    else:
        to_drop.add(f1)

# Keep the reduced feature set
reduced_features = [f for f in Volume_selected.columns if f not in to_drop]
final_Volume = Volume_selected[reduced_features]

print("Dropped features:", to_drop)
print("Remaining features:", reduced_features)
print("Shape before:", Volume_selected.shape, " | after:", final_Volume.shape)
# Out:
# Dropped features: {'Online Shopping', 'Telkom', 'Samsung.1', 'Online banking', 'Sneakers'}
# Remaining features: ['Football', 'Avon', 'We Buy Cars', 'Soccer Laduma', 'The Courier Guy', 'Vodacom', 'Property24', 'Standard Bank', 'Game', 'Gmail', 'MTN', 'Tickets', 'YouTube', 'Pick n Pay', 'Goojara movies', 'Samsung', 'Disney+', 'Huawei', 'DStv Stream', 'Guest House', 'AutoTrader', 'laptop', 'Cars for Sale', 'Nike']
# Shape before: (2365, 29)  | after: (2365, 24)

# %%
final_Volume.head()
# Out:
#             Football  Avon  We Buy Cars  Soccer Laduma  The Courier Guy  \
# date
# 2018-12-30        82    34            7             12                0
# 2018-12-31        53    29            5             12                0
# 2019-01-01        78    39            9             12                0
# 2019-01-02        64    42           11             16                0
# 2019-01-03        64    45           13             16                0
#
#             Vodacom  Property24  Standard Bank  Game  Gmail  ...  \
# date                                                         ...
# 2018-12-30       46          23             30    11     17  ...
# 2018-12-31       58          22             55    13     20  ...
# 2019-01-01       54          30             33    13     17  ...
# 2019-01-02       67          31             53    13     27  ...
# 2019-01-03       65          34             52    12     32  ...
#
#             Goojara movies  Samsung  Disney+  Huawei  DStv Stream  \
# date
# 2018-12-30               0       59       39      19            0
# 2018-12-31               0       59       21      18            0
# 2019-01-01               0       62       36      15            0
# 2019-01-02               0       67       32      21            0
# 2019-01-03               0       64       23      20            0
#
#             Guest House  AutoTrader  laptop  Cars for Sale  Nike
# date
# 2018-12-30           37          17      34             25    55
# 2018-12-31           36          15      31             20    49
# 2019-01-01           27          20      30             27    49
# 2019-01-02           28          22      47             30    54
# 2019-01-03           25          23      38             27    43
#
# [5 rows x 24 columns]

# %%
# Save to CSV 
final_Volume.to_csv("selected_google_trends_volume.csv")

print("Saved selected features  to 'selected_google_trends_volume.csv'")
final_Volume.head()
# Out:
# Saved selected features  to 'selected_google_trends_volume.csv'
#             Football  Avon  We Buy Cars  Soccer Laduma  The Courier Guy  \
# date
# 2018-12-30        82    34            7             12                0
# 2018-12-31        53    29            5             12                0
# 2019-01-01        78    39            9             12                0
# 2019-01-02        64    42           11             16                0
# 2019-01-03        64    45           13             16                0
#
#             Vodacom  Property24  Standard Bank  Game  Gmail  ...  \
# date                                                         ...
# 2018-12-30       46          23             30    11     17  ...
# 2018-12-31       58          22             55    13     20  ...
# 2019-01-01       54          30             33    13     17  ...
# 2019-01-02       67          31             53    13     27  ...
# 2019-01-03       65          34             52    12     32  ...
#
#             Goojara movies  Samsung  Disney+  Huawei  DStv Stream  \
# date
# 2018-12-30               0       59       39      19            0
# 2018-12-31               0       59       21      18            0
# 2019-01-01               0       62       36      15            0
# 2019-01-02               0       67       32      21            0
# 2019-01-03               0       64       23      20            0
#
#             Guest House  AutoTrader  laptop  Cars for Sale  Nike
# date
# 2018-12-30           37          17      34             25    55
# 2018-12-31           36          15      31             20    49
# 2019-01-01           27          20      30             27    49
# 2019-01-02           28          22      47             30    54
# 2019-01-03           25          23      38             27    43
#
# [5 rows x 24 columns]
